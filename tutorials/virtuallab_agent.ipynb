# %%
import sys
import os
current_dir = os.getcwd()
REPO_BASE_DIR = os.path.dirname(os.path.abspath(current_dir))
sys.path.append(REPO_BASE_DIR)

from dotenv import load_dotenv
load_dotenv(os.path.join(REPO_BASE_DIR, ".env"))
# Out:
# True

# %%
from biodsa.agents.virtuallab import VirtualLabAgent, CODING_RULES

# Initialize agent
agent = VirtualLabAgent(
    model_name="gpt-5",
    api_type="azure",
    api_key=os.environ.get("AZURE_OPENAI_API_KEY"),
    endpoint=os.environ.get("AZURE_OPENAI_ENDPOINT"),
    num_rounds=1,
)

# Create participants
pi = agent.create_participant(
    title="Principal Investigator",
    expertise="bioinformatics and computational biology",
    goal="develop useful tools for biological data analysis",
    role="lead the discussion and make decisions",
)

ml_specialist = agent.create_participant(
    title="Bioinformatics Developer",
    expertise="Python programming and sequence analysis",
    goal="write clean, efficient code for biological applications",
    role="implement computational solutions",
)

# Round 1: Discuss requirements for a simple utility function
res1 = agent.go(
    """
    We need a simple Python function to calculate GC content of a DNA sequence.
    
    Please discuss:
    1. What should the function be named?
    2. What input validation should it include?
    3. Should it handle both uppercase and lowercase sequences?
    4. What should it return (percentage or fraction)?
    """,
    None,
    meeting_type="individual",
    team_member=pi,
)
# Out:
# 2026-01-25 20:31:34,999 - WARNING - Failed to initialize sandbox: Error while fetching server API version: ('Connection aborted.', ConnectionRefusedError(61, 'Connection refused'))
# 2026-01-25 20:31:34,999 - WARNING - Tools will fall back to local execution when possible
# ============================================================
# Virtual Lab Individual Meeting
# ============================================================
# Participant: Principal Investigator
# Critic Rounds: 1
# ============================================================
#
# [Principal Investigator] Initial response...
# 2026-01-25 20:31:54,095 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# [Principal Investigator] Response: Thanks for the agenda. Here are my decisions and rationale, followed by a simple implementation we can use immediately.
#
# 1) Function name
# - gc_content
# Rationale: concise, descriptive, and standard in ...
#
# [Scientific Critic] Round 1/1...
# 2026-01-25 20:32:30,559 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# [Scientific Critic] Feedback: Overall adherence to agenda
# - You addressed all four agenda points (name, input validation, case handling, return type) and provided rationale. That’s good. However, one claim needs correction: “allow...
#
# ============================================================
# MEETING COMPLETE
# ============================================================
# Thanks for the agenda. Here are my decisions and rationale, followed by a simple implementation we can use immediately.
#
# 1) Function name
# - gc_content
# Rationale: concise, descriptive, and standard in bioinformatics. It aligns with Python naming conventions (snake_case) and clearly communicates the return value as the GC content.
#
# 2) Input validation
# - Type: require a string; raise TypeError if not.
# - Whitespace: strip out whitespace (spaces, tabs, newlines) so FASTA-formatted sequences can be passed directly.
# - Empty: raise ValueError if the resulting sequence is empty.
# - Alphabet: for a simple, predictable first version, allow only A, C, G, T (case-insensitive). Raise ValueError with the set of offending characters if anything else is present (e.g., N, R, gaps, digits).
#   - Rationale: this keeps the definition clear and avoids silently skewing the denominator. If we need to handle ambiguous IUPAC codes later, we can add options (e.g., ignore ambiguous bases in the denominator, or incl
# ...

# %%
# Round 2: Implement based on Round 1's specification
res2 = agent.go(
    """
    Based on the discussion, write the Python function for calculating GC content.
    Include docstring and type hints.
    """,
    res1,
    meeting_type="individual",
    team_member=ml_specialist,
    agenda_rules=list(CODING_RULES),
    num_rounds=1,
)

# Print results
print("\n" + "=" * 70)
print("ROUND 1 - Requirements Discussion:")
print("=" * 70)
print(res1.final_response)

print("\n" + "=" * 70)
print("ROUND 2 - Implementation:")
print("=" * 70)
print(res2.final_response)
# Out:
# ============================================================
# Virtual Lab Individual Meeting
# ============================================================
# Participant: Bioinformatics Developer
# Critic Rounds: 1
# ============================================================
#
# [Bioinformatics Developer] Initial response...
# 2026-01-25 20:32:52,944 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# [Bioinformatics Developer] Response: #!/usr/bin/env python3
# """
# GC content calculator module.
#
# Provides a function to compute GC content of a DNA sequence and a command-line
# interface for convenience.
#
# Behavior summary:
# - Accepts a strin...
#
# [Scientific Critic] Round 1/1...
# 2026-01-25 20:33:25,306 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# [Scientific Critic] Feedback: Overall, the submission adheres well to both the prior specification and the agenda rules. It provides a self-contained, complete implementation with appropriate imports, no undefined variables, no ps...
#
# ============================================================
# MEETING COMPLETE
# ============================================================
# #!/usr/bin/env python3
# """
# GC content calculator module.
#
# Provides a function to compute GC content of a DNA sequence and a command-line
# interface for convenience.
#
# Behavior summary:
# - Accepts a string sequence.
# - Removes all whitespace characters (spaces, tabs, newlines).
# - Validates that only A, C, G, T characters are present (case-insensitive).
# - Returns the GC content as a fraction (0.0–1.0) by default, or as a percentage
#   (0.0–100.0) when requested.
# """
#
# from typing import Final
# import argparse
#
#
# def gc_content(seq: str, as_percent: bool = False) -> float:
#     """
#     Calculate the GC content of a DNA sequence.
#
#     Rules:
#     - Input must be a string. A TypeError is raised otherwise.
#     - All whitespace characters are removed so that multi-line inputs are supported.
#     - Only canonical DNA bases A, C, G, T (case-insensitive) are allowed.
#       Any other character results in a ValueError.
#     - Case-insensitive counting is performed by normalizing to uppercase.
#
#     Parameters:
# ...
#
# ======================================================================
# ROUND 1 - Requirements Discussion:
# ======================================================================
# Thanks for the agenda. Here are my decisions and rationale, followed by a simple implementation we can use immediately.
#
# 1) Function name
# - gc_content
# Rationale: concise, descriptive, and standard in bioinformatics. It aligns with Python naming conventions (snake_case) and clearly communicates the return value as the GC content.
#
# 2) Input validation
# - Type: require a string; raise TypeError if not.
# - Whitespace: strip out whitespace (spaces, tabs, newlines) so FASTA-formatted sequences can be passed directly.
# - Empty: raise ValueError if the resulting sequence is empty.
# - Alphabet: for a simple, predictable first version, allow only A, C, G, T (case-insensitive). Raise ValueError with the set of offending characters if anything else is present (e.g., N, R, gaps, digits).
#   - Rationale: this keeps the definition clear and avoids silently skewing the denominator. If we need to handle ambiguous IUPAC codes later, we can add options (e.g., ignore ambiguous bases in the denominator, or include them).
#
# 3) Uppercase vs lowercase
# - Yes, handle both by normalizing to uppercase before counting.
#   - Rationale: users often mix case; normalization ensures consistent behavior and better performance with str.count.
#
# 4) Return type
# - Return a fraction between 0 and 1 by default.
#   - Rationale: fractions are easier to compose in downstream calculations and are common in programmatic pipelines.
# - Provide an option to return percentage via a flag.
#   - Proposed flag name: as_percent (default False). When True, return 0–100.
#
# Proposed implementation
# def gc_content(seq: str, as_percent: bool = False) -> float:
#     if not isinstance(seq, str):
#         raise TypeError("seq must be a string")
#
#     # Remove whitespace to allow multi-line or FASTA-like input
#     cleaned = "".join(ch for ch in seq if not ch.isspace()).upper()
#
#     if not cleaned:
#         raise ValueError("Sequence is empty after removing whitespace")
#
#     # Validate allowed alphabet (ACGT only for this simple version)
#     allowed = set("ACGT")
#     invalid = {ch for ch in cleaned if ch not in allowed}
#     if invalid:
#         raise ValueError(f"Invalid characters found: {sorted(invalid)}")
#
#     gc = cleaned.count("G") + cleaned.count("C")
#     frac = gc / len(cleaned)
#
#     return frac * 100.0 if as_percent else frac
#
# Examples
# - gc_content("ATGC") -> 0.5
# - gc_content("atgc", as_percent=True) -> 50.0
# - gc_content("A T\nG C") -> 0.5
# - gc_content("ATGN") -> raises ValueError (by design for simplicity)
#
# Future extensions (if needed)
# - Allow ambiguous IUPAC bases and choose whether to include them in the denominator (e.g., parameter include_ambiguous_in_denominator=False and a separate count_ambiguous_as_gc option).
# - Option to ignore gaps (“-”) or other alignment artifacts.
# - Return both fraction and counts (e.g., a small dataclass or tuple) if needed in downstream QC summaries.
#
# If this spec looks good, I’ll put the function into our utility module and add unit tests for typical and edge cases.
#
# ======================================================================
# ROUND 2 - Implementation:
# ======================================================================
# #!/usr/bin/env python3
# """
# GC content calculator module.
#
# Provides a function to compute GC content of a DNA sequence and a command-line
# interface for convenience.
#
# Behavior summary:
# - Accepts a string sequence.
# - Removes all whitespace characters (spaces, tabs, newlines).
# - Validates that only A, C, G, T characters are present (case-insensitive).
# - Returns the GC content as a fraction (0.0–1.0) by default, or as a percentage
#   (0.0–100.0) when requested.
# """
#
# from typing import Final
# import argparse
#
#
# def gc_content(seq: str, as_percent: bool = False) -> float:
#     """
#     Calculate the GC content of a DNA sequence.
#
#     Rules:
#     - Input must be a string. A TypeError is raised otherwise.
#     - All whitespace characters are removed so that multi-line inputs are supported.
#     - Only canonical DNA bases A, C, G, T (case-insensitive) are allowed.
#       Any other character results in a ValueError.
#     - Case-insensitive counting is performed by normalizing to uppercase.
#
#     Parameters:
#         seq: The input DNA sequence. Whitespace will be removed prior to validation.
#         as_percent: When True, return GC content as a percentage (0.0–100.0).
#                     When False (default), return a fraction (0.0–1.0).
#
#     Returns:
#         GC content as a float. Fraction by default, percentage when as_percent=True.
#
#     Raises:
#         TypeError: If seq is not a string.
#         ValueError: If the sequence is empty after removing whitespace,
#                     or contains invalid characters.
#
#     """
#     if not isinstance(seq, str):
#         raise TypeError("seq must be a string")
#
#     # Remove whitespace to allow multi-line input
#     cleaned: str = "".join(ch for ch in seq if not ch.isspace()).upper()
#
#     if not cleaned:
#         raise ValueError("Sequence is empty after removing whitespace")
#
#     # Validate allowed alphabet (ACGT only for this version)
#     allowed: Final[set[str]] = set("ACGT")
#     invalid = {ch for ch in cleaned if ch not in allowed}
#     if invalid:
#         # Show offending characters in sorted order for reproducibility
#         raise ValueError(f"Invalid characters found: {''.join(sorted(invalid))}")
#
#     gc = cleaned.count("G") + cleaned.count("C")
#     frac = gc / len(cleaned)
#
#     return frac * 100.0 if as_percent else frac
#
#
# def main() -> None:
#     """
#     Command-line interface to compute GC content.
#
#     Usage:
#         python gc_content.py --sequence "ATGC..." [--as-percent]
#
#     Options:
#         --sequence / -s: DNA sequence string. Whitespace will be removed.
#                          Allowed characters: A, C, G, T (case-insensitive).
#         --as-percent: Return GC content as percentage (0–100). Default is fraction.
#
#     Prints:
#         The GC content value to stdout.
#     """
#     parser = argparse.ArgumentParser(
#         description="Calculate GC content of a DNA sequence (ACGT only)."
#     )
#     parser.add_argument(
#         "-s",
#         "--sequence",
#         type=str,
#         required=True,
#         help="DNA sequence string. Whitespace will be removed. Allowed: A,C,G,T (case-insensitive).",
#     )
#     parser.add_argument(
#         "--as-percent",
#         action="store_true",
#         help="Return GC content as percentage (0–100). Default returns fraction (0–1).",
#     )
#     args = parser.parse_args()
#
#     result = gc_content(args.sequence, as_percent=args.as_percent)
#     # Print as a float; avoid excessive formatting to keep output simple and parse-friendly.
#     print(result)
#
#
# if __name__ == "__main__":
#     main()
