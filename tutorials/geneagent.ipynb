# %%
import sys
import os
current_dir = os.getcwd()
REPO_BASE_DIR = os.path.dirname(os.path.abspath(current_dir))
sys.path.append(REPO_BASE_DIR)

from dotenv import load_dotenv
load_dotenv(os.path.join(REPO_BASE_DIR, ".env"))
# Out:
# True

# %%
from biodsa.agents.geneagent import GeneAgent

agent = GeneAgent(
    model_name="gpt-5",
    api_type="azure",
    api_key=os.environ.get("AZURE_OPENAI_API_KEY"),
    endpoint=os.environ.get("AZURE_OPENAI_ENDPOINT"),
    # Quick demo settings (comment out for full verification)
    max_claims_per_stage=2,      # Limit to 2 claims per stage (default: None = all)
    max_verification_rounds=3,   # Limit tool calls per claim (default: 20)
)

# Example gene set from the original GeneAgent paper (MAPK signaling pathway genes)
gene_set = "ERBB2,ERBB4,FGFR2,FGFR4,HRAS,KRAS"

results = agent.go(gene_set)
# Out:
# 2026-01-25 19:28:32,646 - WARNING - Failed to initialize sandbox: Error while fetching server API version: ('Connection aborted.', ConnectionRefusedError(61, 'Connection refused'))
# 2026-01-25 19:28:32,647 - WARNING - Tools will fall back to local execution when possible
# ==================================================
# Stage 1: Generating Initial Analysis
# ==================================================
# 2026-01-25 19:28:55,323 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# Initial Process: ERBB/FGFR-driven RAS–MAPK mitogenic signaling
#
# Initial Summary:
# Process: ERBB/FGFR-driven RAS–MAPK mitogenic signaling
#
# Receptor tyrosine kinase activation and dimerization (ERBB2, ERBB4, FGFR2, FGFR4): ERBB4 and FGFRs bind extracellular ligands and dimerize, enabling trans-autophosphorylation of their intracellular kinase domains. ERBB2 lacks a high-affinity ligand but is a preferred heterodimerization partner that increases phosphorylation site density and signaling potency when paired with ligand-bound ERBB family members. This mechanism is supported by e...
# ==================================================
# Stage 2: Generating Topic Claims
# ==================================================
# 2026-01-25 19:29:11,926 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# Limiting claims from 7 to 2 (quick mode)
#
# Topic Claims to Verify: ['ERBB2,ERBB4,FGFR2,FGFR4,HRAS,KRAS participate in ERBB/FGFR-driven activation of the RAS–MAPK pathway that promotes mitogenic signaling', 'ERBB2,ERBB4,FGFR2,FGFR4 act as upstream receptor tyrosine kinases that activate HRAS and KRAS to propagate RAS–MAPK mitogenic signaling']
#
# Verifying claim 1/2: ERBB2,ERBB4,FGFR2,FGFR4,HRAS,KRAS participate in ERBB_FGFR-driven activation of the RAS_MAPK pathway...
# 2026-01-25 19:29:18,905 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-25 19:29:38,152 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-25 19:30:19,058 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# Verification result: Supported_Pathway analysis evidence_The gene set ERBB2, ERBB4, FGFR2, FGFR4, HRAS, KRAS is annotated to the MAPK signaling pathway with all six genes overlapping (ERBB4, ERBB2, KRAS, FGFR4, HRAS, FGFR...
#
# Verifying claim 2/2: ERBB2,ERBB4,FGFR2,FGFR4 act as upstream receptor tyrosine kinases that activate HRAS and KRAS to pro...
# 2026-01-25 19:30:28,830 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-25 19:31:32,272 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# Verification result: Decision_ Supported_Pathway evidence_ The MAPK signaling pathway (KEGG) includes ERBB2, ERBB4, FGFR2, FGFR4 together with HRAS and KRAS, indicating these receptor tyrosine kinases and RAS isoforms par...
# ==================================================
# Stage 3: Updating Process Name
# ==================================================
# 2026-01-25 19:31:56,397 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# Updated Process: ERBB and FGFR driven RAS MAPK mitogenic signaling
#
# Updated Summary:
# Process: ERBB and FGFR driven RAS MAPK mitogenic signaling
#
# Receptor tyrosine kinase ligand binding, dimerization, and autophosphorylation (ERBB2, ERBB4, FGFR2, FGFR4): KEGG MAPK pathway annotation includes these receptors together with HRAS and KRAS, and NCBI Gene summaries state that ERBB4 and FGFRs are ligand activated while ERBB2 enhances signaling through heterodimerization with EGF receptor family members. BioPlanet terms for SHC1 events in ERBB2 signaling and FRS2 mediated cascade support...
# ==================================================
# Stage 4: Generating Analysis Claims
# ==================================================
# 2026-01-25 19:32:19,727 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# Limiting claims from 20 to 2 (quick mode)
#
# Analysis Claims to Verify: ['ERBB2 heterodimerizes with other EGFR family receptors to recruit SHC1 and GRB2, initiating SOS-mediated RAS activation and MAPK signaling.', 'ERBB4 binds neuregulin ligands and promotes SHC1/GRB2-SOS recruitment to activate RAF-MEK-ERK–dependent mitogenesis.']
#
# Verifying claim 1/2: ERBB2 heterodimerizes with other EGFR family receptors to recruit SHC1 and GRB2, initiating SOS-medi...
# 2026-01-25 19:32:44,960 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-25 19:33:06,323 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-25 19:33:31,284 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# Verification result: Supported_Evidence_The ERBB2 gene summary states that ERBB2 binds tightly to other ligand-bound EGF receptor family members to form a heterodimer, stabilizing ligand binding and enhancing kinase-media...
#
# Verifying claim 2/2: ERBB4 binds neuregulin ligands and promotes SHC1_GRB2-SOS recruitment to activate RAF-MEK-ERK_depend...
# 2026-01-25 19:33:41,647 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-25 19:34:02,014 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# 2026-01-25 19:34:20,465 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# Verification result: Failed to verify claim within maximum rounds....
# ==================================================
# Stage 5: Generating Final Summary
# ==================================================
# 2026-01-25 19:34:54,639 - INFO - HTTP Request: POST https://zifeng-gpt-2.openai.azure.com/openai/deployments/gpt-5/chat/completions?api-version=2024-12-01-preview "HTTP/1.1 200 OK"
# Final Process: ERBB and FGFR driven RAS MAPK mitogenic signaling
#
# Final Summary:
# Process: ERBB and FGFR driven RAS MAPK mitogenic signaling
#
# Receptor tyrosine kinase heterodimerization and activation (ERBB2, ERBB4, FGFR2, FGFR4): KEGG MAPK pathway annotation includes these receptors with HRAS and KRAS, and ERBB and ErbB signaling pathways are enriched for the gene set. The ERBB2 gene summary states ERBB2 tightly binds other ligand-bound EGF receptor family members to form heterodimers, stabilizing ligand binding and enhancing kinase-mediated activation of MAPK and PI3K pathways. Pathway terms such as SHC1 events in ERBB2 signaling and ERBB2 role in signal transduction align with adaptor docking on receptor phosphotyrosines.
#
# Adaptor mediated recruitment and SOS driven RAS activation (ERBB2, HRAS, KRAS): SHC1 gene summary indicates p52Shc and p46Shc link activated receptor tyrosine kinases to the Ras pathway by recruiting the GRB2 SOS complex, and GRB2 gene summary describes SH2 dependent binding to phosphorylated receptors or SHC1 and SH3 dependent recruitment of SOS1. Protein interactions show ERBB2 with SHC1 and GRB2, GRB2 with SOS1, SHC1 with SOS1, and a GTPase HRAS SOS1 complex, supporting GDP to GTP exchange on HRAS and KRAS.
#
# MAPK cascade activation and mitogenic output (HRAS, KRAS, ERBB2, FGFR2, FGFR4, ERBB4): Interactions include KRAS with RAF1 and MAPK1 with MAP2K1, and pathway enrichment for ErbB signaling and ERBB signaling contains ERBB2 together with MAPK axis members, supporting RAF MEK ERK activation downstream of HRAS and KRAS. ERBB2 gene summary links receptor activation to MAPK driven mitogenesis.
#
# FGFR scaffolding via FRS2 coupling to RAS MAPK (FGFR2, FGFR4, HRAS, KRAS): BioPlanet FRS2 mediated cascade overlaps FGFR2, FGFR4, HRAS, KRAS, supporting FGFR recruitment of FRS2 and GRB2 SOS to activate HRAS and KRAS and drive the MAPK pathway.
#
# PI3K Akt branching from RTKs and RAS (ERBB2, ERBB4, FGFR2, FGFR4, HRAS, KRAS): Gene set enrichment identifies PI3K Akt signaling, and ERBB2 gene summary notes activation of PI3K alongside MAPK. RAS engages PI3K, providing parallel survival and growth signals coordinated with mitogenic MAPK output.
#
# Signal amplification through ERBB2 heterodimerization (ERBB2, HRAS, KRAS): ERBB2 heterodimers increase adaptor engagement, supported by pathway SHC1 events in ERBB2 signaling and interaction counts for ERBB2 with SHC1 and EGFR, which strengthen SOS mediated activation of HRAS and KRAS and enhance MAPK signaling.

# %%
print(results.final_response)
# Out:
# # Gene Set Analysis Results
#
# ## Gene Set
# ERBB2,ERBB4,FGFR2,FGFR4,HRAS,KRAS
#
# ## Final Analysis
# Process: ERBB and FGFR driven RAS MAPK mitogenic signaling
#
# Receptor tyrosine kinase heterodimerization and activation (ERBB2, ERBB4, FGFR2, FGFR4): KEGG MAPK pathway annotation includes these receptors with HRAS and KRAS, and ERBB and ErbB signaling pathways are enriched for the gene set. The ERBB2 gene summary states ERBB2 tightly binds other ligand-bound EGF receptor family members to form heterodimers, stabilizing ligand binding and enhancing kinase-mediated activation of MAPK and PI3K pathways. Pathway terms such as SHC1 events in ERBB2 signaling and ERBB2 role in signal transduction align with adaptor docking on receptor phosphotyrosines.
#
# Adaptor mediated recruitment and SOS driven RAS activation (ERBB2, HRAS, KRAS): SHC1 gene summary indicates p52Shc and p46Shc link activated receptor tyrosine kinases to the Ras pathway by recruiting the GRB2 SOS complex, and GRB2 gene summary describes SH2 dependent binding to phosphorylated receptors or SHC1 and SH3 dependent recruitment of SOS1. Protein interactions show ERBB2 with SHC1 and GRB2, GRB2 with SOS1, SHC1 with SOS1, and a GTPase HRAS SOS1 complex, supporting GDP to GTP exchange on HRAS and KRAS.
#
# MAPK cascade activation and mitogenic output (HRAS, KRAS, ERBB2, FGFR2, FGFR4, ERBB4): Interactions include KRAS with RAF1 and MAPK1 with MAP2K1, and pathway enrichment for ErbB signaling and ERBB signaling contains ERBB2 together with MAPK axis members, supporting RAF MEK ERK activation downstream of HRAS and KRAS. ERBB2 gene summary links receptor activation to MAPK driven mitogenesis.
#
# FGFR scaffolding via FRS2 coupling to RAS MAPK (FGFR2, FGFR4, HRAS, KRAS): BioPlanet FRS2 mediated cascade overlaps FGFR2, FGFR4, HRAS, KRAS, supporting FGFR recruitment of FRS2 and GRB2 SOS to activate HRAS and KRAS and drive the MAPK pathway.
#
# PI3K Akt branching from RTKs and RAS (ERBB2, ERBB4, FGFR2, FGFR4, HRAS, KRAS): Gene set enrichment identifies PI3K Akt signaling, and ERBB2 gene summary notes activation of PI3K alongside MAPK. RAS engages PI3K, providing parallel survival and growth signals coordinated with mitogenic MAPK output.
#
# Signal amplification through ERBB2 heterodimerization (ERBB2, HRAS, KRAS): ERBB2 heterodimers increase adaptor engagement, supported by pathway SHC1 events in ERBB2 signaling and interaction counts for ERBB2 with SHC1 and EGFR, which strengthen SOS mediated activation of HRAS and KRAS and enhance MAPK signaling.
#
# ## Topic Verification Report
# Original_claim:ERBB2,ERBB4,FGFR2,FGFR4,HRAS,KRAS participate in ERBB_FGFR-driven activation of the RAS_MAPK pathway that promotes mitogenic signaling
# Verified_claim:Supported_Pathway analysis evidence_The gene set ERBB2, ERBB4, FGFR2, FGFR4, HRAS, KRAS is annotated to the MAPK signaling pathway with all six genes overlapping (ERBB4, ERBB2, KRAS, FGFR4, HRAS, FGFR2) in KEGG_2021_Human._Additional pathway terms directly link ERBB and FGFR signaling to RAS_MAPK activation, including SHC1 events in ERBB2 signaling (ERBB4, ERBB2, KRAS, HRAS) and FRS2-mediated cascade (KRAS, FGFR4, HRAS, FGFR2) from BioPlanet_2019._functions.get_pathway_for_gene_set_Enrichment analysis evidence_The MAPK signaling pathway (KEGG_04010) is significantly enriched for the gene set with intersection size 6 of 6 and p_value 9.31e-08; precision 1.0. PI3K-Akt signaling pathway is also significantly enriched, consistent with ERBB_FGFR RTK signaling branching._functions.get_enrichment_for_gene_set_Protein interaction evidence consistent with ERBB_FGFR_RAS_MAPK coupling_ERBB2 interacts with SHC1 and GRB2, adaptor proteins that recruit SOS to activate Ras._HRAS and KRAS interact with RAF1 and SOS1, canonical members of the Ras_Raf_MEK_ERK cascade._FGFR signaling adapters and ligands are present (e.g., FGFR4 with FGF19; FGFR2 with FGF23), consistent with upstream activation._functions.get_interactions_for_gene_set_Gene summary evidence indicating RTK-driven mitogenic signaling via MAPK_ERBB2 summary states it enhances activation of downstream signaling pathways including MAPK and PI3K through heterodimerization with other EGF receptors, aligning with ERBB-driven RAS_MAPK activation._ERBB4 summary states that activation induces mitogenesis and differentiation, consistent with ERBB-driven promotion of mitogenic signaling._FGFR2 summary states FGF binding initiates downstream signals ultimately influencing mitogenesis and differentiation, consistent with FGFR-driven MAPK activation._FGFR4 summary similarly states downstream signaling influences mitogenesis and differentiation._HRAS and KRAS summaries confirm their roles as small GTPases in signal transduction, consistent with RAS nodes in the MAPK pathway._functions.get_gene_summary_for_single_gene for ERBB2, ERBB4, FGFR2, FGFR4, HRAS, KRAS_PubMed literature evidence linking ERBB_FGFR to Ras_MAPK activation_PMID_ 28781955 reports ErbB2 signaling epigenetically suppresses miR-205 via the Ras_Raf_MEK_ERK pathway in breast cancer, directly implicating ERBB2-driven activation of Ras_MAPK._PMID_ 40289214 shows GRB2 promotes malignancy in HER2-positive breast cancer by regulating the Ras_MAPK pathway, supporting ERBB2_GRB2_Ras_MAPK signaling._PMID_ 20043086 demonstrates ErbB2-enhanced invasiveness of H-Ras-activated breast cells, with MAPK involvement, supporting ERBB2 and H-Ras interplay in MAPK-driven phenotypes._PMID_ 17085783 shows neuregulin-induced ErbB4 activation engages PI3K and Ras_MapK signaling in PC12-ErbB4 cells, consistent with ERBB4-driven Ras_MAPK._PMID_ 40170241 shows FGFR2 upregulation cooperates with mutant KRAS to drive pancreatic tumorigenesis, and FGFR2 abrogation reduces MAPK pathway activation, indicating FGFR2_RAS_MAPK involvement._PMID_ 23696246 (review) states FGF receptor signaling to the RAS-MAPK branch is a major mediator of downstream responses, supporting FGFR2_FGFR4 involvement in Ras_MAPK._PMID_ 25053532 (review) affirms FGFRs regulate tumorigenesis through four main pathways including RAS-MAPK, underscoring FGFR-driven activation of this cascade._PMID_ 15863030 (review) details FGFR docking proteins FRS2_ as major mediators of Ras_MAPK signaling, supporting FGFR_FRS2_Ras_MAPK activation._functions.get_pubmed_articles for ERBB2 RAS MAPK signaling; ERBB4 RAS MAPK signaling; FGFR2 RAS MAPK signaling; FGFR4 RAS MAPK signaling_Conclusion_Across pathway and enrichment analyses, interaction data, authoritative gene summaries, and multiple PubMed articles and reviews, there is consistent evidence that ERBB2 and ERBB4 (ERBB family RTKs) and FGFR2 and FGFR4 (FGFR family RTKs) activate the RAS_MAPK pathway via canonical adaptor-mediated mechani ...
#
# Original_claim:ERBB2,ERBB4,FGFR2,FGFR4 act as upstream receptor tyrosine kinases that activate HRAS and KRAS to propagate RAS_MAPK mitogenic signaling
# Verified_claim:Decision_ Supported_Pathway evidence_ The MAPK signaling pathway (KEGG) includes ERBB2, ERBB4, FGFR2, FGFR4 together with HRAS and KRAS, indicating these receptor tyrosine kinases and RAS isoforms participate in the same upstream-to-downstream cascade. Source_ Pathway analysis returned _MAPK signaling pathway_ with overlapping genes ERBB4, ERBB2, KRAS, FGFR4, HRAS, FGFR2 (KEGG_2021_Human). Additionally, BioPlanet terms _SHC1 events in ERBB2 signaling_ (overlapping ERBB4, ERBB2, KRAS, HRAS) and _FRS2-mediated cascade_ (overlapping KRAS, FGFR4, HRAS, FGFR2) support ERBB and FGFR adaptor-mediated linkage to RAS-MAPK._Enrichment evidence_ GO molecular function enrichment identified transmembrane receptor protein tyrosine kinase activity and transmembrane receptor protein kinase activity as significant for the gene set including ERBB2, ERBB4, FGFR2, FGFR4, HRAS, KRAS, consistent with ERBB and FGFR family members acting as upstream receptor tyrosine kinases that initiate downstream signaling including MAPK._Interaction evidence_ Protein-protein interaction results show ERBB2 interacts with GRB2 and SHC1, and ERBB4 interacts with SHC1, consistent with recruitment of adaptor proteins that couple RTKs to RAS activation via SOS. HRAS interacts with SOS1 and RAF1, and KRAS interacts with RAF1 and SHOC2, consistent with activated RAS propagating signals to the RAF-MEK-ERK MAPK cascade._Gene-level evidence_ ERBB2 (NCBI Gene) is an epidermal growth factor receptor family receptor tyrosine kinase that enhances activation of downstream pathways including mitogen-activated protein kinase. ERBB4 (NCBI Gene) encodes a receptor tyrosine kinase activated by neuregulins that induces mitogenesis and differentiation. FGFR2 (NCBI Gene) is a receptor tyrosine kinase that binds FGFs and triggers downstream cascades influencing mitogenesis. FGFR4 (NCBI Gene) is a receptor tyrosine kinase for FGFs involved in regulating proliferation and differentiation. HRAS and KRAS (NCBI Gene) are small GTPases functioning in signal transduction, acting downstream to relay signals to RAF-MEK-ERK._Literature evidence linking ERBBs to RAS-MAPK_PMID_ 28781955 ErbB2 signaling epigenetically suppresses microRNA-205 transcription via the Ras_Raf_MEK_ERK pathway in breast cancer, directly supporting ERBB2 engagement of the RAS-MAPK cascade._PMID_ 40289214 GRB2 promotes brain metastasis in HER2-positive breast cancer by regulating the Ras_MAPK pathway, implicating HER2_ERBB2 with adaptor GRB2 in activating the RAS-MAPK pathway._PMID_ 18335053 Topological analysis indicates EGFR_ErbB4 heterodimers preferentially engage Grb2-SOS to drive Ras activation leading to ERK signaling, supporting ERBB4 as an upstream activator of Ras_MAPK._Literature evidence linking FGFRs to RAS-MAPK_PMID_ 15863030 Cellular signaling by FGFRs shows that FGFR stimulation phosphorylates docking proteins (FRS2_), which mediate activation of the Ras_MAPK pathway, consistent with FGFR2 and FGFR4 acting upstream of Ras-MAPK._PMID_ 25053532 Review of FGFRs states FGFRs regulate tumorigenesis through main pathways including RAS-MAPK, consistent with FGFR2 and FGFR4 upstream of RAS-MAPK signaling._PMID_ 23696246 Review on FGFs reiterates that FGF signaling drives the RAS-MAPK branch; FGFR2 and FGFR4 are included among FGFRs signaling to RAS-MAPK._PMID_ 40170241 FGFR2 abrogation reduces MAPK pathway activation and intercepts KRAS-driven pancreatic tumorigenesis, indicating FGFR2 contributes upstream input to KRAS-MAPK signaling in vivo._Overall assessment_ Multiple independent lines of evidence from pathway databases (KEGG, BioPlanet), gene function summaries (NCBI Gene), protein interactions (GRB2_SHC1 with ERBBs; SOS1_RAF with RAS), and peer-reviewed studies support that ERBB2, ERBB4, FGFR2, and FGFR4 are upstream receptor tyrosine kinases that, via adaptor proteins like SHC1, FRS2, and GRB2-SOS, activate RAS isoforms (including HRAS and KRAS) to propagate mitogenic RAS-MAPK signaling.
#
#
#
# ## Analysis Verification Report
# Original_claim:ERBB2 heterodimerizes with other EGFR family receptors to recruit SHC1 and GRB2, initiating SOS-mediated RAS activation and MAPK signaling.
# Verified_claim:Supported_Evidence_The ERBB2 gene summary states that ERBB2 binds tightly to other ligand-bound EGF receptor family members to form a heterodimer, stabilizing ligand binding and enhancing kinase-mediated activation of downstream signalling pathways, such as those involving mitogen-activated protein kinase and phosphatidylinositol-3 kinase. Source_ functions.get_gene_summary_for_single_gene for ERBB2._The SHC1 gene summary states that p52Shc and p46Shc link activated receptor tyrosine kinases to the Ras pathway by recruitment of the GRB2_SOS complex. Source_ functions.get_gene_summary_for_single_gene for SHC1._The GRB2 gene summary states that GRB2 binds the epidermal growth factor receptor, with SH3 domains directing complex formation with proline-rich regions of other proteins and the SH2 domain binding tyrosine phosphorylated sequences, consistent with recruitment of SOS1 via SH3 domains and binding to phosphorylated SHC1 or receptor tails via SH2. Source_ functions.get_gene_summary_for_single_gene for GRB2._Protein-protein interaction evidence shows the key connections among the claim_s components. Returned interactions include ERBB2 with SHC1 (count 9), EGFR with ERBB2 (count 7), EGFR with SHC1 (count 13), EGFR with GRB2 (count 11), GRB2 with SOS1 (count 14), SHC1 with SOS1 (count 8), KRAS with RAF1 (count 6), and MAPK1 with MAP2K1 (count 6). These support heterodimerization, recruitment of SHC1 and GRB2, SOS-mediated RAS activation, and downstream MAPK signaling. Source_ functions.get_interactions_for_gene_set for ERBB2,EGFR,ERBB3,SHC1,GRB2,SOS1,KRAS,MAPK1._Pathway analysis results include SHC1 events in ERBB2 signaling, ERBB2 role in signal transduction and oncology, ErbB signaling pathway, ERBB signaling pathway, and SHC1 Events In ERBB2 Signaling R-HSA-1250196. Overlapping genes in these pathways include ERBB3, SHC1, ERBB2, MAPK1, GRB2, KRAS, SOS1, EGFR, aligning directly with the mechanisms in the claim. Source_ functions.get_pathway_for_gene_set for ERBB2,EGFR,ERBB3,SHC1,GRB2,SOS1,KRAS,MAPK1._Gene set enrichment confirms significant association with ErbB signaling pathway and ERBB signaling pathway, consistent with the described signal transduction cascade. Source_ functions.get_enrichment_for_gene_set for ERBB2,EGFR,ERBB3,SHC1,GRB2,SOS1,KRAS,MAPK1._Protein complex information identifies GTPase HRAS _ SOS1 complexes, directly supporting SOS-mediated RAS activation as part of the pathway. Source_ functions.get_complex_for_gene_set for ERBB2,EGFR,ERBB3,SHC1,GRB2,SOS1,KRAS,MAPK1._Attempts to retrieve PubMed articles using the provided queries did not return results with the search terms, but multiple other tool outputs above provide literature-mined and database-curated evidence that collectively support the claim. Sources_ functions.get_pubmed_articles.
#
# Original_claim:ERBB4 binds neuregulin ligands and promotes SHC1_GRB2-SOS recruitment to activate RAF-MEK-ERK_dependent mitogenesis.
# Verified_claim:Failed to verify claim within maximum rounds.
#
#
#
# ## Statistics
# - Total claims verified: 4
